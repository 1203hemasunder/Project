# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("C:\Geethanjali\Sample.csv")

# %%
dataset
# Out:
#      MODEL        MAKE                      MODEL.1             VEHICLE CLASS  \
# 0     2001       ACURA                        1.7EL                   COMPACT
# 1     2001       ACURA                        1.7EL                   COMPACT
# 2     2001       ACURA                        3.2CL                   COMPACT
# 3     2001       ACURA                        3.2TL                  MID-SIZE
# 4     2001       ACURA                        3.5RL                  MID-SIZE
# 5     2001       ACURA                      INTEGRA                SUBCOMPACT
# 6     2001       ACURA                      INTEGRA                SUBCOMPACT
# 7     2001       ACURA                 INTEGRA GS-R                SUBCOMPACT
# 8     2001       ACURA                          MDX                       SUV
# 9     2001       ACURA                          NSX                TWO-SEATER
# 10    2001       ACURA                          NSX                TWO-SEATER
# ...

# %%
dataset.head()
# Out:
#    MODEL   MAKE MODEL.1 VEHICLE CLASS  ENGINE_SIZE  CYLINDERS TRANSMISSION  \
# 0   2001  ACURA   1.7EL       COMPACT          1.7          4           A4
# 1   2001  ACURA   1.7EL       COMPACT          1.7          4           M5
# 2   2001  ACURA   3.2CL       COMPACT          3.2          6          AS5
# 3   2001  ACURA   3.2TL      MID-SIZE          3.2          6          AS5
# 4   2001  ACURA   3.5RL      MID-SIZE          3.5          6           A4
#
#   FUEL  FUEL_CONSUMPTION*  Unnamed: 9  Unnamed: 10  Unnamed: 11  CO2_EMISSIONS
# 0    X                9.3         7.2          8.3           34            191
# 1    X                8.9         7.4          8.3           34            191
# 2    Z               13.7         8.8         11.5           25            265
# 3    Z               13.8         8.8         11.6           24            267
# 4    Z               15.0        10.9         13.1           22            301

# %%
dataset.drop('MODEL',axis=1,inplace=True)

# %%
dataset.columns
# Out:
# Index(['MAKE', 'MODEL.1', 'VEHICLE CLASS', 'ENGINE_SIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUEL', 'FUEL_CONSUMPTION*', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'CO2_EMISSIONS'],
#       dtype='object')

# %%
dataset.columns=['Make','MODEL.1', 'Vehicle_Class', 'Engine_Size', 'Cylinders',
       'Transmission', 'Fuel_Type', 'Fuel_Consumption_City',
       'Fuel_Consumption_Hwy', 'Fuel_Consumption_Comb(L/100 km)',
       'Fuel_Consumption_Comb(mpg)','CO2_Emissions'] # manually giving the name  of the columns
dataset.columns
# Out:
# Index(['Make', 'MODEL.1', 'Vehicle_Class', 'Engine_Size', 'Cylinders',
#        'Transmission', 'Fuel_Type', 'Fuel_Consumption_City',
#        'Fuel_Consumption_Hwy', 'Fuel_Consumption_Comb(L/100 km)',
#        'Fuel_Consumption_Comb(mpg)', 'CO2_Emissions'],
#       dtype='object')

# %%
dataset["MAKE"].mode()[0]
# Out:
# 'FORD'

# %%
dataset["MODEL.1"].mode()[0]
# Out:
# 'RAM 1500'

# %%
dataset["VEHICLE CLASS"].mode()[0]
# Out:
# 'COMPACT'

# %%
dataset["TRANSMISSION"].mode()[0]
# Out:
# 'A4'

# %%
dataset['FUEL'].mode()[0]
# Out:
# 'X'

# %%
dataset['MAKE'].unique()
# Out:
# array(['ACURA', 'AUDI', 'BMW', 'BUICK', 'CADILLAC', 'CHEVROLET',
#        'CHRYSLER', 'DAEWOO', 'DODGE', 'FORD', 'GMC', 'HONDA', 'HYUNDAI',
#        'INFINITI', 'ISUZU', 'JAGUAR', 'JEEP', 'KIA', 'LEXUS', 'LINCOLN',
#        'MAZDA', 'MERCEDES-BENZ', 'NISSAN', 'OLDSMOBILE', 'PLYMOUTH',
#        'PONTIAC', 'PORSCHE', 'SAAB', 'SATURN', 'SUBARU', 'SUZUKI',
#        'TOYOTA', 'VOLKSWAGEN', 'VOLVO'], dtype=object)

# %%
dataset['MODEL.1'].unique()
# Out:
# array(['1.7EL', '3.2CL', '3.2TL', '3.5RL', 'INTEGRA', 'INTEGRA GS-R',
#        'MDX', 'NSX', 'A4', 'A4 QUATTRO', 'A6', 'A6 AVANT QUATTRO WAGON',
#        'A6 QUATTRO', 'A8 L', 'A8 QUATTRO', 'ALLROAD', 'S4 QUATTRO',
#        'S8 QUATTRO #', 'TT COUPE QUATTRO', 'TT COUPE QUATTRO #',
#        'TT ROADSTER', 'TT ROADSTER QUATTRO #', '320i', '325Ci',
#        '325Ci CONVERTIBLE', '325i', '325xi', '330Ci', '330Ci CONVERTIBLE',
#        '330i', '330xi', '525i', '525i SPORT WAGON', '530i', '540i',
#        '540i SPORT WAGON', '740i', '740iL', '750iL', 'M COUPE',
#        'M ROADSTER', 'M3', 'M3 CONVERTIBLE', 'M5', 'X5', 'Z3', 'Z8',
#        'CENTURY', 'LESABRE', 'PARK AVENUE', 'PARK AVENUE #', 'REGAL',
#        'REGAL #', 'CATERA', 'DEVILLE', 'ELDORADO', 'SEVILLE',
#        'ASTRO CARGO', 'ASTRO CARGO AWD', 'ASTRO PASSENGER',
#        'ASTRO PASSENGER AWD', 'BLAZER', 'BLAZER 4X4', 'C1500 SILVERADO',
#        'C1500 SUBURBAN', 'C1500 TAHOE', 'CAMARO', 'CAVALIER',
# ...

# %%
dataset['VEHICLE CLASS'].unique()
# Out:
# array(['COMPACT', 'MID-SIZE', 'SUBCOMPACT', 'SUV', 'TWO-SEATER',
#        'STATION WAGON - MID-SIZE', 'FULL-SIZE', 'MINICOMPACT',
#        'STATION WAGON - SMALL', 'VAN - CARGO', 'VAN - PASSENGER',
#        'PICKUP TRUCK - STANDARD', 'PICKUP TRUCK - SMALL', 'MINIVAN'],
#       dtype=object)

# %%
dataset['TRANSMISSION'].unique()
# Out:
# array(['A4', 'M5', 'AS5', 'A5', 'AS4', 'M6', 'A3', 'AV'], dtype=object)

# %%
dataset['FUEL'].unique()
# Out:
# array(['X', 'Z', 'E', 'N', 'D'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset["MAKE"] = le.fit_transform(dataset["MAKE"])
dataset["MODEL.1"] = le.fit_transform(dataset["MODEL.1"])
dataset["VEHICLE CLASS"] = le.fit_transform(dataset["VEHICLE CLASS"])
dataset["TRANSMISSION"] = le.fit_transform(dataset["TRANSMISSION"])
dataset["FUEL"] = le.fit_transform(dataset["FUEL"])

# %%
dataset.head(8)
# Out:
#    MODEL  MAKE  MODEL.1  VEHICLE CLASS  ENGINE_SIZE  CYLINDERS  TRANSMISSION  \
# 0   2001     0        0              0          1.7          4             1
# 1   2001     0        0              0          1.7          4             6
# 2   2001     0        1              0          3.2          6             4
# 3   2001     0        2              2          3.2          6             4
# 4   2001     0        3              2          3.5          6             1
# 5   2001     0      166              9          1.8          4             1
# 6   2001     0      166              9          1.8          4             6
# 7   2001     0      167              9          1.8          4             6
#
#    FUEL  FUEL_CONSUMPTION*  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0     3                9.3         7.2          8.3           34
# 1     3                8.9         7.4          8.3           34
# 2     4               13.7         8.8         11.5           25
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 13 columns):
# MODEL                679 non-null int64
# MAKE                 679 non-null int32
# MODEL.1              679 non-null int32
# VEHICLE CLASS        679 non-null int32
# ENGINE_SIZE          679 non-null float64
# CYLINDERS            679 non-null int64
# TRANSMISSION         679 non-null int32
# FUEL                 679 non-null int32
# FUEL_CONSUMPTION*    679 non-null float64
# Unnamed: 9           679 non-null float64
# Unnamed: 10          679 non-null float64
# Unnamed: 11          679 non-null int64
# CO2_EMISSIONS        679 non-null int64
# dtypes: float64(4), int32(5), int64(4)
# memory usage: 55.8 KB

# %%
dataset.describe()
# Out:
#         MODEL        MAKE     MODEL.1  VEHICLE CLASS  ENGINE_SIZE   CYLINDERS  \
# count   679.0  679.000000  679.000000     679.000000   679.000000  679.000000
# mean   2001.0   15.275405  171.291605       5.421208     3.252577    5.798233
# std       0.0   10.498455   98.867513       4.203092     1.203751    1.531073
# min    2001.0    0.000000    0.000000       0.000000     1.000000    3.000000
# 25%    2001.0    6.000000   84.500000       1.000000     2.200000    4.000000
# 50%    2001.0   11.000000  169.000000       6.000000     3.000000    6.000000
# 75%    2001.0   25.000000  252.500000       9.500000     4.200000    6.000000
# max    2001.0   33.000000  350.000000      13.000000     8.000000   12.000000
#
#        TRANSMISSION        FUEL  FUEL_CONSUMPTION*  Unnamed: 9  Unnamed: 10  \
# count    679.000000  679.000000         679.000000  679.000000   679.000000
# mean       2.946981    3.284242          14.591900   10.613844    12.802798
# ...

# %%
x = dataset.iloc[:,1:12].values
y = dataset.iloc[:,12].values
print(x)
# Out:
# [[  0.    0.    0.  ...   7.2   8.3  34. ]
#  [  0.    0.    0.  ...   7.4   8.3  34. ]
#  [  0.    1.    0.  ...   8.8  11.5  25. ]
#  ...
#  [ 33.  328.    7.  ...   9.3  11.   26. ]
#  [ 33.  329.    7.  ...  10.3  12.5  23. ]
#  [ 33.  330.   10.  ...  11.4  13.3  21. ]]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([("oh", OneHotEncoder(),[1,2,4,5])],remainder = "passthrough")
x = ct.fit_transform(x)
# Out:
# C:\Users\VENU\Anaconda5\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
np.unique(dataset.dtypes,return_counts=True)
# Out:
# (array([dtype('int32'), dtype('int64'), dtype('float64')], dtype=object),
#  array([5, 4, 4], dtype=int64))

# %%
cat = dataset.dtypes[dataset.dtypes=='O'].index.values
cat
# Out:
# array([], dtype=object)

# %%
dataset.isnull().sum()
# Out:
# MODEL                0
# MAKE                 0
# MODEL.1              0
# VEHICLE CLASS        0
# ENGINE_SIZE          0
# CYLINDERS            0
# TRANSMISSION         0
# FUEL                 0
# FUEL_CONSUMPTION*    0
# Unnamed: 9           0
# Unnamed: 10          0
# Unnamed: 11          0
# CO2_EMISSIONS        0
# dtype: int64

# %%
for i in cat:
    print("Column :",i)
    print('count of classes :',dataset[i].nunique())
    print(c(dataset[i]))
    print('*'*120)

# %%
import joblib
joblib.dump(ct,"column")
# Out:
# ['column']

# %%
x[0]
# Out:
# array([2.001e+03, 0.000e+00, 0.000e+00, 0.000e+00, 1.700e+00, 4.000e+00,
#        1.000e+00, 3.000e+00, 9.300e+00, 7.200e+00, 8.300e+00, 3.400e+01])

# %%
plt.scatter(dataset.MAKE, dataset.CO2_EMISSIONS)
plt.xlabel("MAKE")
plt.ylabel("CO2_EMISSIONS")
# Out:
# Text(0, 0.5, 'CO2_EMISSIONS')

# %%
import seaborn as sns
corr = dataset.corr()
plt.subplots(figsize=(16,8));
sns.heatmap(corr,annot = True,square = True)
plt.title("correlation matrix of numerical features")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,6))
corr["CO2_EMISSIONS"].sort_values(ascending = True)[:-1].plot(kind = "barh")

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset["CO2_EMISSIONS"] = le.fit_transform(dataset["CO2_EMISSIONS"])

# %%
x = dataset.iloc[:,0:12].values
y = dataset.iloc[:,12].values

# %%
x
# Out:
# array([[2.001e+03, 0.000e+00, 0.000e+00, ..., 7.200e+00, 8.300e+00,
#         3.400e+01],
#        [2.001e+03, 0.000e+00, 0.000e+00, ..., 7.400e+00, 8.300e+00,
#         3.400e+01],
#        [2.001e+03, 0.000e+00, 1.000e+00, ..., 8.800e+00, 1.150e+01,
#         2.500e+01],
#        ...,
#        [2.001e+03, 3.300e+01, 3.280e+02, ..., 9.300e+00, 1.100e+01,
#         2.600e+01],
#        [2.001e+03, 3.300e+01, 3.290e+02, ..., 1.030e+01, 1.250e+01,
#         2.300e+01],
#        [2.001e+03, 3.300e+01, 3.300e+02, ..., 1.140e+01, 1.330e+01,
#         2.100e+01]])

# %%
y
# Out:
# array([ 10,  10,  43,  44,  60,  28,  23,  24,  64,  62,  63,  41,  28,
#         53,  43,  33,  56,  54,  57,  62,  60,  61,  62,  60,  60,  60,
#         79,  75,  60,  61,  80,  41,  41,  35,  41,  40,  37,  43,  38,
#         47,  47,  43,  38,  47,  46,  41,  37,  51,  55,  41,  37,  55,
#         44,  43,  38,  47,  47,  51,  37,  57,  67,  68,  63,  63,  92,
#         59,  59,  66,  70,  92,  76,  80,  93,  44,  43,  47,  38,  92,
#         40,  43,  43,  50,  46,  50,  63,  57,  57,  57,  65,  81,  70,
#         91,  65,  78,  81,  99,  70,  80,  80,  90,  89, 101,  85, 101,
#         42,  42,  56,  47,  29,  31,  39,  35,  29,  56,  47,  90, 100,
#        104,  96, 100, 107,  31,  46,  81,  99,  85, 108,  94, 106,  85,
#        103,  40,  31,  46,  65,  78,  96,  98,  52,  48,  41,  34,  26,
#         37,  38,  37,  38,  49,  54,  43,  50,  43,  42,  50,  54,  54,
#         27,  16,  21,  49,  45,  38,  43,  42,  43,  42,  42,  47,  47,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)
print(x_train.shape)
print(x_test.shape)
# Out:
# (543, 12)
# (136, 12)

# %%
from sklearn.linear_model  import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x_test
# Out:
# array([[2.001e+03, 5.000e+00, 9.600e+01, ..., 1.020e+01, 1.270e+01,
#         2.200e+01],
#        [2.001e+03, 3.100e+01, 7.500e+01, ..., 9.500e+00, 1.170e+01,
#         2.400e+01],
#        [2.001e+03, 2.000e+01, 5.400e+01, ..., 1.200e+01, 1.390e+01,
#         2.000e+01],
#        ...,
#        [2.001e+03, 2.300e+01, 2.870e+02, ..., 9.800e+00, 1.200e+01,
#         2.400e+01],
#        [2.001e+03, 3.100e+01, 7.500e+01, ..., 8.100e+00, 1.000e+01,
#         2.800e+01],
#        [2.001e+03, 2.000e+00, 3.500e+02, ..., 1.230e+01, 1.620e+01,
#         1.700e+01]])

# %%
y_test
# Out:
# array([ 56,  45,  68,  16,  61,  75,  47,  88,  36,  12,  43,  31,  99,
#         40,  88,  78,  38,  30,  92,  70,  90,  43,  43,  42,  85,  85,
#         70,  64,  44,  41,  26,  61, 103,  26,  19,  20,  57,  54,  94,
#         46,  38,  58,  67,  37,  94,  41,  65,  33,  38,  38,  38,  44,
#         37, 105,  27,  43,  43,  10,  60,  68,  38,  35, 106,  59,  19,
#         41,  69,  23,  43,  55,  41,  31,  65,  39,  85,  92,  44,  37,
#        114,  99,  76,  38,  51,  40,  38,  54,  83,  52,  53,  42,  57,
#         51,  88,  47,  41,  52,  52,  47, 101,  41,   9,  40,  16,  24,
#         54,  83,  48,  37,  60,  34,  77,  47,  39,  85,  63,  64,  25,
#         64,   7,  71,  41,  31, 101,  63,  42, 107,  40,  37,  66,  94,
#         80,  61,  41,  49,  27,  92], dtype=int64)

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 61.07473218,  44.62203396,  67.5991985 ,  19.21005889,
#         62.64810133,  73.85334902,  49.15697465,  85.22970843,
#         37.05315834,  15.3008241 ,  41.85129303,  32.30786018,
#         97.52485376,  39.00922706,  86.31375831,  76.47464327,
#         39.16420011,  32.2702103 ,  89.66623791,  67.26924683,
#         88.13281197,  43.53974536,  45.32606794,  40.62759553,
#         81.43184495,  82.19522307,  69.3714918 ,  63.65513616,
#         43.0606557 ,  39.99707443,  28.61169995,  65.00550144,
#         99.35494028,  27.48972209,  21.73570382,  22.08609279,
#         57.86787685,  52.12840718,  94.07805325,  45.54211136,
#         40.20435976,  58.65814561,  66.1207496 ,  37.02137965,
#         91.97900556,  41.18575813,  63.95221038,  33.76612866,
#         37.81994934,  38.45807684,  37.62432484,  43.57734274,
#         38.59385514, 102.25964686,  28.56913154,  43.27998335,
#         41.87650276,  15.29134993,  61.47952934,  69.8532433 ,
# ...

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
print("MSE:",metrics.mean_absolute_error(y_test,y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 2.295583301497707
# MSE: 2.295583301497707
# RMSE: 5.570640522617029

# %%
import pickle
pickle.dump(LinearRegression,open('CO2.pkl','wb'))

# %%
pwd
# Out:
# 'C:\\geethanjali'
